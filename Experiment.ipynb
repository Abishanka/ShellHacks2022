# %%
import pandas as pd
import random
import numpy as np

df = pd.read_csv (r'Data/Data.csv')

# %%
df.head(35)
# Out:
#      security_id      cusip    sedol          isin        ric   bloomberg  \
# 0   BBG00BVB6S99  G9887T108      NaN  KYG9887T1085        NaN  48572203.0
# 1   BBG0015HYBQ4        NaN      NaN           NaN  BAJAX0:NS         NaN
# 2   BBG00188KJM3        NaN      NaN           NaN  IGASX0:NS         NaN
# 3   BBG0016YXRN5        NaN      NaN           NaN  SUTVZ0:NS         NaN
# 4   BBG0016YXR19        NaN      NaN           NaN  TITNZ0:NS         NaN
# 5   BBG000VR99Q8        NaN      NaN           NaN  PWFCV0:NS         NaN
# 6   BBG000VR8774        NaN      NaN           NaN  BAJEV0:NS         NaN
# 7   BBG0015HY7Z3        NaN      NaN           NaN  REDYX0:NS         NaN
# 8   BBG0015HY8Y2        NaN      NaN           NaN  GAILX0:NS         NaN
# 9   BBG00188KL02        NaN      NaN           NaN  IGASZ0:NS         NaN
# 10  BBG0016YXQW7        NaN      NaN           NaN  DIVIZ0:NS         NaN
# 11  BBG001894YY3        NaN      NaN           NaN  TTCHF1:NS         NaN
# ...

# %%
data = df.to_numpy()

# %%
data.shape
# Out:
# (599613, 11)

# %%
print(type(data[0][1]))
# Out:
# <class 'str'>

# %%
list_ = [0] * 100

# %%
list_[0]
# Out:
# 0

# %%
import numpy as np
list = []
arr = np.array(list)
print(arr)
print(len(arr))
# Out:
# []
# 0

# %%
count = 0

# %%
while (len(arr) < 1000):
    num = random.randint(0, 25000)
    if (isinstance(data[num][1], str)):
        length = len(data[num][1])
#         print(length)
#         print(data[num][1])
        #ind_begin = random.randint(0,length/2)
        a = random.randint(0,length/3)
        str1 = data[num][1][a : (a + 4)]
        list__ = []
        arr__ = np.array(list__)
        arr__ = np.append(arr__, str1)
        arr__ = np.append(arr__, data[num][0])
       # cur[1] = data[num][0]
#         print(data[num][0])
#         print(cur)
#         print(type(cur))
       # cur = cur.append(data[num][0])
#         list_[count] = cur
        arr = np.append(arr,arr__)
        count = count + 1
       # print(count)

# %%
arr.shape
# Out:
# (1000,)

# %%
arr[1]
# Out:
# 'BBG00L991L24'

# %%
print(arr)
# Out:
# ['59J2' 'BBG00L991L24' 'S302' 'BBG00NZSZ8V9' '9108' 'BBG00YRDCJQ4' 'BQ36'
#  'BBG011P0JZV6' '8327' 'BBG00002TGP0' '0445' 'BBG002PXX8Z3' 'F179'
#  'BBG0000362G4' 'Q335' 'BBG011N21MC3' '9128' 'BBG000DKP1M6' '86BE'
#  'BBG00LW7X9C3' '796K' 'BBG011VCVSX3' '1171' 'BBG00YB9P5N9' 'H695'
#  'BBG0000GFTD9' '7859' 'BBG015SVF8K2' '7937' 'BBG00KSP43L5' '931T'
#  'BBG01259VZ98' 'QJ12' 'BBG00B5C23H6' '8262' 'BBG00HCXXK14' '0049'
#  'BBG00GH83JQ5' '4599' 'BBG000H8K6S7' '133E' 'BBG00LG7FNH5' '0024'
#  'BBG000BB6F57' '6428' 'BBG000PNJ9F5' '306B' 'BBG010S1D2P9' 'T105'
#  'BBG000BBKYH7' '0123' 'BBG00YZ2NPM7' '0342' 'BBG00BTBTQJ0' '3602'
#  'BBG00TQDR4Y4' 'X301' 'BBG000005547' '2827' 'BBG00NDHJG74' 'EK72'
#  'BBG0081G6QB9' '10H1' 'BBG000BGYHB4' 'P821' 'BBG00RM41XT2' 'BK43'
#  'BBG00VYHKCC4' '0777' 'BBG000BD89X4' '44ZJ' 'BBG00009R580' 'P052'
#  'BBG00FVH8C09' '1358' 'BBG0000077X9' 'P056' 'BBG00MDXSS84' '76B1'
#  'BBG011384SM5' '2587' 'BBG00J89QHK2' '5986' 'BBG00PMFP0M4' '4503'
# ...

# %%
import csv
f = open('cusip_data_3.csv', 'w')
x = 0
while x < len(arr):
    row = (str(arr[x]) + ',' + str(arr[x+1])) +"\n"
    f.write(row)
    x+=2
f.close()
